# %% [markdown]
# # Week 2 - Preprocessing, part 2
#
# # 1. Lesson: None

# %% [markdown]
# # 2. Weekly graph question

# %% [markdown]
# The Storytelling With Data book mentions planning on a "Who, What, and How" for your data story.  Write down a possible Who, What, and How for your data, using the ideas in the book.

# %%
# Healthcare Expenditure Drivers and Hospital Efficiency

## The WHO


## The WHAT


## The HOW

# %% [markdown]
# # 3. Homework - work with your own data

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %% [markdown]
# This week, you will do the same types of exercises as last week, but you should use your chosen datasets that someone in your class found last semester. (They likely will not be the particular datasets that you found yourself.)
#
# ### Here are some types of analysis you can do  Use Google, documentation, and ChatGPT to help you:
#
# - Summarize the datasets using info() and describe()
#
# - Are there any duplicate rows?
#
# - Are there any duplicate values in a given column (when this would be inappropriate?)
#
# - What are the mean, median, and mode of each column?
#
# - Are there any missing or null values?
#
#     - Do you want to fill in the missing value with a mean value?  A value of your choice?  Remove that row?
#
# - Identify any other inconsistent data (e.g. someone seems to be taking an action before they are born.)
#
# - Encode any categorical variables (e.g. with one-hot encoding.)
#
# ### Conclusions:
#
# - Are the data usable?  If not, find some new data!
#
# - Do you need to modify or correct the data in some way?
#
# - Is there any class imbalance?  (Categories that have many more items than other categories).

# %%
# Creating DF for Hospital Provider Cost Report 

df_provider = pd.read_csv('Hospital_Provider_Cost_Report_2022.csv')

# %%
# Dataset Info

pd.set_option('display.max_columns', None) # Stop column list for being cut off
df_provider.info(verbose=True) # With verbose, it lists out the columns used in the dataset. Viewed as a scrollable list
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6064 entries, 0 to 6063
# Data columns (total 117 columns):
#  #    Column                                                                   Dtype
# ---   ------                                                                   -----
#  0    rpt_rec_num                                                              int64
#  1    Provider CCN                                                             int64
#  2    Hospital Name                                                            str
#  3    Street Address                                                           str
#  4    City                                                                     str
#  5    State Code                                                               str
#  6    Zip Code                                                                 str
#  7    County                                                                   str
# ...

# %%
# Decribe Dataset

df_provider.describe(include='all') # To describe all the columns in dataset
# Describe does not work on str variables, need to do changes on the dataset to change non category columns to float or int datatypes
# Out:
#           rpt_rec_num   Provider CCN                         Hospital Name  \
# count     6064.000000    6064.000000                                  6064
# unique            NaN            NaN                                  5727
# top               NaN            NaN  ENCOMPASS HEALTH REHABILITATION HOSP
# freq              NaN            NaN                                   116
# mean    754291.104387  269404.638522                                   NaN
# std      10770.303579  160322.536510                                   NaN
# min     717629.000000   10001.000000                                   NaN
# 25%     745140.750000  140157.250000                                   NaN
# 50%     755650.500000  260021.000000                                   NaN
# 75%     762052.750000  393035.250000                                   NaN
# max     776832.000000  713029.000000                                   NaN
#
# ...

# %%
# Check for duplicate records

df_provider.duplicated().sum() # No duplicate rows returned from the Dataset
# Out:
# np.int64(0)

# %%
# Check for duplicate records per column (when this would be inappropriate?)

for col in df_provider.columns:
    duplicate_column_count = df_provider.duplicated(subset=[col], keep=False).sum()
    print(f'Duplicate count in column "{col}": {duplicate_column_count}')

# All the column by itself expect rpt_rec_num contain duplicate values
# The column rpt_rec_num currently contains no duplicate values. This column is a unique (primary key)"system-generated 
# sequence number assigned by CMS". It would be inappropriate for this column to contain duplicates.
# Out:
# Duplicate count in column "rpt_rec_num"": 0
# Duplicate count in column "Provider CCN"": 127
# Duplicate count in column "Hospital Name"": 494
# Duplicate count in column "Street Address"": 277
# Duplicate count in column "City"": 3920
# Duplicate count in column "State Code"": 6063
# Duplicate count in column "Zip Code"": 1315
# Duplicate count in column "County"": 5287
# Duplicate count in column "Medicare CBSA Number"": 6022
# Duplicate count in column "Rural Versus Urban"": 6064
# Duplicate count in column "CCN Facility Type"": 6064
# Duplicate count in column "Provider Type"": 6063
# Duplicate count in column "Type of Control"": 6064
# Duplicate count in column "Fiscal Year Begin Date"": 6007
# Duplicate count in column "Fiscal Year End Date"": 6020
# Duplicate count in column "FTE - Employees on Payroll"": 656
# Duplicate count in column "Number of Interns and Residents (FTE)"": 4828
# Duplicate count in column "Total Days Title V"": 5947
# ...

# %%
# Mean, Median and Mode of Each column

# %% [markdown]
# # 4. Storytelling With Data graph

# %% [markdown]
# Just like last week: choose any graph in the Introduction of Storytelling With Data. Use matplotlib to reproduce it in a rough way. I don't expect you to spend an enormous amount of time on this; I understand that you likely will not have time to re-create every feature of the graph. However, if you're excited about learning to use matplotlib, this is a good way to do that. You don't have to duplicate the exact values on the graph; just the same rough shape will be enough.  If you don't feel comfortable using matplotlib yet, do the best you can and write down what you tried or what Google searches you did to find the answers.
